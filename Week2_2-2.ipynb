# %%
import pandas as pd

# %%
fruits = ["Elma", "Armut", "Kiraz"]
fruits
# Out:
# ['Elma', 'Armut', 'Kiraz']

# %%
pd.Series(fruits)
# Out:
# 0     Elma
# 1    Armut
# 2    Kiraz
# dtype: object

# %%
kırtasiye = {
    "Defter" : 30,
    "Kalem" : 20,
    "Silgi" :10
}
kırtasiye
# Out:
# {'Defter': 30, 'Kalem': 20, 'Silgi': 10}

# %%
pd.Series(kırtasiye)
# Out:
# Defter    30
# Kalem     20
# Silgi     10
# dtype: int64

# %%
sayilar = pd.Series([1, 2, 3, 1.5])

# %%
sayilar.sum() # toplam
sayilar.mean() # aritmatik ortalama
sayilar.product() # çarpım
sayilar.std() #standart sapma
sayilar.min() # minimum değer
sayilar.max() # minimum değer
sayilar.median() #medyan
sayilar.mode() # mode
# Out:
# 0    1.0
# 1    1.5
# 2    2.0
# 3    3.0
# dtype: float64

# %%
deneme = pd.Series([1, 2, 3, "Soru"])

# %%
try:
    deneme.sum()
except:
    print("Hata")
# Out:
# Hata

# %%
len(deneme)
# Out:
# 4

# %%
deneme.size
# Out:
# 4

# %%
deneme2 = pd.Series([1, 2, 3, None])
deneme2
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# dtype: float64

# %%
deneme2.size
# Out:
# 4

# %%
deneme2.count()
# Out:
# 3

# %%
deneme.is_unique
# Out:
# True

# %%
deneme3 = pd.Series([1, 2, 3, 2])
deneme3.is_unique
# Out:
# False

# %%
deneme3
# Out:
# 0    1
# 1    2
# 2    3
# 3    2
# dtype: int64

# %%
deneme.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
deneme.values
# Out:
# array([1, 2, 3, 'Soru'], dtype=object)

# %%
gunler = ["Pazartesi", "Salı", "Çarşamba"]
meyveler = ["Elma", "Portakal", "Muz"]

pd.Series(meyveler, gunler)
# Out:
# Pazartesi        Elma
# Salı         Portakal
# Çarşamba          Muz
# dtype: object

# %%
pd.Series(index=gunler, data=meyveler)
# Out:
# Pazartesi        Elma
# Salı         Portakal
# Çarşamba          Muz
# dtype: object

# %%
df = pd.read_csv("resources/pokemon.csv")
df
# Out:
#         Pokemon     Type
# 0     Bulbasaur    Grass
# 1       Ivysaur    Grass
# 2      Venusaur    Grass
# 3    Charmander     Fire
# 4    Charmeleon     Fire
# ..          ...      ...
# 716     Yveltal     Dark
# 717     Zygarde   Dragon
# 718     Diancie     Rock
# 719       Hoopa  Psychic
# 720   Volcanion     Fire
#
# [721 rows x 2 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_csv("resources/pokemon.csv", usecols=["Pokemon"])
# Out:
#         Pokemon
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# ..          ...
# 716     Yveltal
# 717     Zygarde
# 718     Diancie
# 719       Hoopa
# 720   Volcanion
#
# [721 rows x 1 columns]

# %%
seri = pd.read_csv("resources/pokemon.csv", 
                   usecols=["Pokemon"]).squeeze("columns")
seri
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
#           ...
# 716       Yveltal
# 717       Zygarde
# 718       Diancie
# 719         Hoopa
# 720     Volcanion
# Name: Pokemon, Length: 721, dtype: object

# %%
type(seri)
# Out:
# pandas.core.series.Series

# %%
seri.head()
seri.head(n=2)
seri.head(2)
# Out:
# 0    Bulbasaur
# 1      Ivysaur
# Name: Pokemon, dtype: object

# %%
seri.tail()
seri.tail(n=2)
seri.tail(2)
# Out:
# 719        Hoopa
# 720    Volcanion
# Name: Pokemon, dtype: object

# %%
dir(seri)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
sorted(seri, reverse=True)
# Out:
# ['Zygarde',
#  'Zweilous',
#  'Zubat',
#  'Zorua',
#  'Zoroark',
#  'Zigzagoon',
#  'Zekrom',
#  'Zebstrika',
#  'Zapdos',
#  'Zangoose',
#  'Yveltal',
#  'Yanmega',
#  'Yanma',
#  'Yamask',
#  'Xerneas',
#  'Xatu',
#  'Wynaut',
#  'Wurmple',
#  'Wormadam',
#  'Wooper',
#  'Woobat',
#  'Wobbuffet',
#  'Wingull',
#  'Wigglytuff',
#  'Whismur',
#  'Whiscash',
#  'Whirlipede',
#  'Whimsicott',
#  'Weezing',
#  'Weepinbell',
#  'Weedle',
#  'Weavile',
#  'Watchog',
#  'Wartortle',
#  'Walrein',
#  'Wailord',
#  'Wailmer',
#  'Vulpix',
#  'Vullaby',
#  'Voltorb',
#  'Volcarona',
#  'Volcanion',
#  'Volbeat',
#  'Vivillon',
#  'Virizion',
#  'Vileplume',
#  'Vigoroth',
#  'Victreebel',
#  'Victini',
#  'Vibrava',
#  'Vespiquen',
#  'Venusaur',
#  'Venonat',
#  'Venomoth',
#  'Venipede',
#  'Vaporeon',
#  'Vanilluxe',
#  'Vanillite',
#  'Vanillish',
#  'Uxie',
#  'Ursaring',
#  'Unown',
#  'Unfezant',
#  'Umbreon',
#  'Tyrunt',
#  'Tyrogue',
#  'Tyrantrum',
#  'Tyranitar',
#  'Typhlosion',
# ...

# %%
list(seri)
# Out:
# ['Bulbasaur',
#  'Ivysaur',
#  'Venusaur',
#  'Charmander',
#  'Charmeleon',
#  'Charizard',
#  'Squirtle',
#  'Wartortle',
#  'Blastoise',
#  'Caterpie',
#  'Metapod',
#  'Butterfree',
#  'Weedle',
#  'Kakuna',
#  'Beedrill',
#  'Pidgey',
#  'Pidgeotto',
#  'Pidgeot',
#  'Rattata',
#  'Raticate',
#  'Spearow',
#  'Fearow',
#  'Ekans',
#  'Arbok',
#  'Pikachu',
#  'Raichu',
#  'Sandshrew',
#  'Sandslash',
#  'Nidoran',
#  'Nidorina',
#  'Nidoqueen',
#  'Nidoran♂',
#  'Nidorino',
#  'Nidoking',
#  'Clefairy',
#  'Clefable',
#  'Vulpix',
#  'Ninetales',
#  'Jigglypuff',
#  'Wigglytuff',
#  'Zubat',
#  'Golbat',
#  'Oddish',
#  'Gloom',
#  'Vileplume',
#  'Paras',
#  'Parasect',
#  'Venonat',
#  'Venomoth',
#  'Diglett',
#  'Dugtrio',
#  'Meowth',
#  'Persian',
#  'Psyduck',
#  'Golduck',
#  'Mankey',
#  'Primeape',
#  'Growlithe',
#  'Arcanine',
#  'Poliwag',
#  'Poliwhirl',
#  'Poliwrath',
#  'Abra',
#  'Kadabra',
#  'Alakazam',
#  'Machop',
#  'Machoke',
#  'Machamp',
# ...

# %%
dict(seri)
# Out:
# {0: 'Bulbasaur',
#  1: 'Ivysaur',
#  2: 'Venusaur',
#  3: 'Charmander',
#  4: 'Charmeleon',
#  5: 'Charizard',
#  6: 'Squirtle',
#  7: 'Wartortle',
#  8: 'Blastoise',
#  9: 'Caterpie',
#  10: 'Metapod',
#  11: 'Butterfree',
#  12: 'Weedle',
#  13: 'Kakuna',
#  14: 'Beedrill',
#  15: 'Pidgey',
#  16: 'Pidgeotto',
#  17: 'Pidgeot',
#  18: 'Rattata',
#  19: 'Raticate',
#  20: 'Spearow',
#  21: 'Fearow',
#  22: 'Ekans',
#  23: 'Arbok',
#  24: 'Pikachu',
#  25: 'Raichu',
#  26: 'Sandshrew',
#  27: 'Sandslash',
#  28: 'Nidoran',
#  29: 'Nidorina',
#  30: 'Nidoqueen',
#  31: 'Nidoran♂',
#  32: 'Nidorino',
#  33: 'Nidoking',
#  34: 'Clefairy',
#  35: 'Clefable',
#  36: 'Vulpix',
#  37: 'Ninetales',
#  38: 'Jigglypuff',
#  39: 'Wigglytuff',
#  40: 'Zubat',
#  41: 'Golbat',
#  42: 'Oddish',
#  43: 'Gloom',
#  44: 'Vileplume',
#  45: 'Paras',
#  46: 'Parasect',
#  47: 'Venonat',
#  48: 'Venomoth',
#  49: 'Diglett',
#  50: 'Dugtrio',
#  51: 'Meowth',
#  52: 'Persian',
#  53: 'Psyduck',
# ...

# %%
seri2 = seri.copy()

# %%
seri2.sort_values(inplace=True)

# %%
seri2
# Out:
# 459    Abomasnow
# 62          Abra
# 358        Absol
# 616     Accelgor
# 680    Aegislash
#          ...
# 570      Zoroark
# 569        Zorua
# 40         Zubat
# 633     Zweilous
# 717      Zygarde
# Name: Pokemon, Length: 721, dtype: object

# %%
seri2 = pd.read_csv("resources/pokemon.csv", 
                    index_col="Pokemon").squeeze("columns")
seri2
# Out:
# Pokemon
# Bulbasaur       Grass
# Ivysaur         Grass
# Venusaur        Grass
# Charmander       Fire
# Charmeleon       Fire
#                ...
# Yveltal          Dark
# Zygarde        Dragon
# Diancie          Rock
# Hoopa         Psychic
# Volcanion        Fire
# Name: Type, Length: 721, dtype: object

# %%
seri2.sort_index(inplace=True)
seri2
# Out:
# Pokemon
# Abomasnow      Grass
# Abra         Psychic
# Absol           Dark
# Accelgor         Bug
# Aegislash      Steel
#               ...
# Zoroark         Dark
# Zorua           Dark
# Zubat         Poison
# Zweilous        Dark
# Zygarde       Dragon
# Name: Type, Length: 721, dtype: object

# %%
"Abra" in seri2
# Out:
# True

# %%
"Rock" in seri2.values
# Out:
# True

# %%
seri2.index
# Out:
# Index(['Abomasnow', 'Abra', 'Absol', 'Accelgor', 'Aegislash', 'Aerodactyl',
#        'Aggron', 'Aipom', 'Alakazam', 'Alomomola',
#        ...
#        'Zangoose', 'Zapdos', 'Zebstrika', 'Zekrom', 'Zigzagoon', 'Zoroark',
#        'Zorua', 'Zubat', 'Zweilous', 'Zygarde'],
#       dtype='object', name='Pokemon', length=721)

# %%
type(seri2.index)
# Out:
# pandas.core.indexes.base.Index

# %%
seri2
# Out:
# Pokemon
# Abomasnow      Grass
# Abra         Psychic
# Absol           Dark
# Accelgor         Bug
# Aegislash      Steel
#               ...
# Zoroark         Dark
# Zorua           Dark
# Zubat         Poison
# Zweilous        Dark
# Zygarde       Dragon
# Name: Type, Length: 721, dtype: object

# %%
seri2["Abra"]
# Out:
# 'Psychic'

# %%
seri2[1]
# Out:
# 'Psychic'

# %%
seri2[[1, 3, 5]]
# Out:
# Pokemon
# Abra          Psychic
# Accelgor          Bug
# Aerodactyl       Rock
# Name: Type, dtype: object

# %%
seri2[["Abra", "Accelgor"]]
# Out:
# Pokemon
# Abra        Psychic
# Accelgor        Bug
# Name: Type, dtype: object

# %%
seri2[0:8]
# Out:
# Pokemon
# Abomasnow       Grass
# Abra          Psychic
# Absol            Dark
# Accelgor          Bug
# Aegislash       Steel
# Aerodactyl       Rock
# Aggron          Steel
# Aipom          Normal
# Name: Type, dtype: object

# %%
seri2[0:8:2]
# Out:
# Pokemon
# Abomasnow    Grass
# Absol         Dark
# Aegislash    Steel
# Aggron       Steel
# Name: Type, dtype: object

# %%
seri2[:3]
# Out:
# Pokemon
# Abomasnow      Grass
# Abra         Psychic
# Absol           Dark
# Name: Type, dtype: object

# %%
seri2[718:]
# Out:
# Pokemon
# Zubat       Poison
# Zweilous      Dark
# Zygarde     Dragon
# Name: Type, dtype: object

# %%
seri2[-1]
# Out:
# 'Dragon'

# %%
seri2[-24:]
# Out:
# Pokemon
# Wigglytuff      Normal
# Wingull          Water
# Wobbuffet      Psychic
# Woobat         Psychic
# Wooper           Water
# Wormadam           Bug
# Wurmple            Bug
# Wynaut         Psychic
# Xatu           Psychic
# Xerneas          Fairy
# Yamask           Ghost
# Yanma              Bug
# Yanmega            Bug
# Yveltal           Dark
# Zangoose        Normal
# Zapdos        Electric
# Zebstrika     Electric
# Zekrom          Dragon
# Zigzagoon       Normal
# Zoroark           Dark
# Zorua             Dark
# Zubat           Poison
# Zweilous          Dark
# Zygarde         Dragon
# Name: Type, dtype: object

# %%
seri2["Abra1"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Abra1'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
seri2.get("Abra1", "Key Yok")
# Out:
# 'Key Yok'

# %%
seri2["Abra"] = "Merhaba"
seri2
# Out:
# Pokemon
# Abomasnow      Grass
# Abra         Merhaba
# Absol           Dark
# Accelgor         Bug
# Aegislash      Steel
#               ...
# Zoroark         Dark
# Zorua           Dark
# Zubat         Poison
# Zweilous        Dark
# Zygarde       Dragon
# Name: Type, Length: 721, dtype: object

# %%
seri2[[0, 2, 4]] = ["A", "L", "İ"]
seri2
# Out:
# Pokemon
# Abomasnow          A
# Abra         Merhaba
# Absol              L
# Accelgor         Bug
# Aegislash          İ
#               ...
# Zoroark         Dark
# Zorua           Dark
# Zubat         Poison
# Zweilous        Dark
# Zygarde       Dragon
# Name: Type, Length: 721, dtype: object

# %%
nba = pd.read_csv("resources/nba.csv")
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
type(nba)
# Out:
# pandas.core.frame.DataFrame

# %%
nba.head(2)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
#
#      College     Salary
# 0      Texas  7730337.0
# 1  Marquette  6796117.0

# %%
nba.tail(2)
# Out:
#             Name       Team  Number Position   Age Height  Weight College  \
# 456  Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457          NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#        Salary
# 456  947276.0
# 457       NaN

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
nba.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, ..., 180.0, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99.0, ..., 235.0, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30.0, ..., 205.0,
#         'Boston University', nan],
#        ...,
#        ['Tibor Pleiss', 'Utah Jazz', 21.0, ..., 256.0, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24.0, ..., 231.0, 'Kansas', 947276.0],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
nba.axes
# Out:
# [RangeIndex(start=0, stop=458, step=1),
#  Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#         'College', 'Salary'],
#        dtype='object')]

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
revenue = pd.read_csv("resources/revenue.csv", index_col="Date")
revenue
# Out:
#          New York  Los Angeles  Miami
# Date
# 1/1/16        985          122    499
# 1/2/16        738          788    534
# 1/3/16         14           20    933
# 1/4/16        730          904    885
# 1/5/16        114           71    253
# 1/6/16        936          502    497
# 1/7/16        123          996    115
# 1/8/16        935          492    886
# 1/9/16        846          954    823
# 1/10/16        54          285    216

# %%
revenue.sum()
revenue.sum(axis=0)
revenue.sum(axis="index")
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
revenue.sum(axis=1)
revenue.sum(axis="columns")
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %%
nba.Name
nba["Name"]
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# 457              NaN
# Name: Name, Length: 458, dtype: object

# %%
nba[["Name", "Number", "Salary"]]
# Out:
#               Name  Number     Salary
# 0    Avery Bradley     0.0  7730337.0
# 1      Jae Crowder    99.0  6796117.0
# 2     John Holland    30.0        NaN
# 3      R.J. Hunter    28.0  1148640.0
# 4    Jonas Jerebko     8.0  5000000.0
# ..             ...     ...        ...
# 453   Shelvin Mack     8.0  2433333.0
# 454      Raul Neto    25.0   900000.0
# 455   Tibor Pleiss    21.0  2900000.0
# 456    Jeff Withey    24.0   947276.0
# 457            NaN     NaN        NaN
#
# [458 rows x 3 columns]

# %%
nba["College"] = "SDÜ"
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#     College     Salary
# 0       SDÜ  7730337.0
# 1       SDÜ  6796117.0
# ...

# %%
nba.to
